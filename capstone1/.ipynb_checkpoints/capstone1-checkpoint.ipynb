# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import states_name as states
import seaborn as sns

# %matplotlib inline
pd.options.display.float_format = '{:,.2f}'.format

plt.style.use("ggplot")

# %%
#zillow columns to use
# zillow_cols = ['RegionID','SizeRank','RegionName','RegionType','StateName','State','Metro','StateCodeFIPS','MunicipalCodeFIPS']
zillow_cols = ['SizeRank','RegionName','State']

#change available dates to COVID dates
start_date = '2019-12-31'
end_date = '2021-02-28'
list_dates = pd.date_range(start_date,end_date, 
              freq='M').strftime("%Y-%m-%d").tolist()

zillow_cols.extend(list_dates)

# %%
#read data from zillow and covid
zillow_df = pd.read_csv('data/zhvi_by_county_all_homes.csv', usecols=zillow_cols)
cov = pd.read_csv('data/covid_by_us_counties.csv')
pd.set_option('display.max_columns', None)

#state/county info
states_df = pd.read_csv('data/states.csv')
landmass_df = pd.read_csv('data/county_landmass.csv')
population_df = pd.read_csv('data/county-pop-2019.csv')

# %%
nyc = ['Kings County, NY', 'Bronx County, NY', 'Queens County, NY', 'New York County, NY', 'Richmond County, NY']
nyc_county = population_df[population_df['county-state'].isin(nyc)]
nyc_population = nyc_county['POPESTIMATE2019'].sum()
population_df.loc[len(population_df.index)] = ['New York City, NY', nyc_population]

# %%
population_df['county-state'] = population_df['county-state'].str.replace(' County','')

# %%
population_df[population_df['county-state'] == 'New York City, NY']
# Out:
#            county-state  POPESTIMATE2019
# 3193  New York City, NY          8336817

# %%
cov_df = cov.merge(states_df,how='left', left_on='state', right_on='state')
cov_df['county-state'] = cov_df['county'] + ", " + cov_df['code']
cov_df.drop(['state','county','code'], axis=1, inplace=True)

# %%
#combine county and state code
zillow_df['county-state'] = zillow_df['RegionName'] + ", " + zillow_df['State']

# %%
#Zillow change in typical value for 6 months and cumulative months.

zillow_df['diff-cumulative'] = zillow_df['2021-02-28'] - zillow_df['2019-12-31']
zillow_df['diff%'] = (zillow_df['2021-02-28'] - zillow_df['2019-12-31']) / zillow_df['2019-12-31'] * 100
zillow_df['positive'] = zillow_df['diff%'] > 0
zillow_df['county-state'] = zillow_df['county-state'].str.replace(' County','')
zillow_df.head()
# Out:
#    SizeRank          RegionName State  2019-12-31  2020-01-31  2020-02-29  \
# 0         0  Los Angeles County    CA  652,445.00  656,768.00  662,606.00
# 1         1         Cook County    IL  253,611.00  254,567.00  254,866.00
# 2         2       Harris County    TX  200,806.00  200,791.00  201,119.00
# 3         3     Maricopa County    AZ  291,097.00  292,733.00  294,850.00
# 4         4    San Diego County    CA  606,929.00  610,781.00  615,269.00
#
#    2020-03-31  2020-04-30  2020-05-31  2020-06-30  2020-07-31  2020-08-31  \
# 0  668,339.00  673,426.00  675,389.00  676,740.00  681,907.00  689,445.00
# 1  255,510.00  255,556.00  256,071.00  256,789.00  258,126.00  259,837.00
# 2  202,085.00  203,217.00  204,199.00  204,923.00  205,836.00  206,945.00
# 3  297,478.00  301,550.00  304,743.00  307,714.00  310,657.00  314,576.00
# 4  620,442.00  624,442.00  628,566.00  631,516.00  635,497.00  641,772.00
#
# ...

# %%
#rearrange Zillow DF columns
new_cols = ['SizeRank','county-state','diff-cumulative','diff%','positive']
new_cols.extend(list_dates)

nyc = ['Kings, NY', 'Bronx, NY', 'Queens, NY']

zillow_df = zillow_df[~zillow_df['county-state'].isin(nyc)]
zillow_df = zillow_df[new_cols]
zillow_df['county-state'].replace('New York, NY','New York City, NY',inplace=True)
top_10 = zillow_df[zillow_df['SizeRank']<101].sort_values('2019-12-31',ascending=False).head(10)
top_10.sort_values('diff%',inplace=True)
top_10
# Out:
#     SizeRank       county-state  diff-cumulative  diff%  positive  \
# 19        19  New York City, NY       -42,033.00  -4.33     False
# 65        65  San Francisco, CA       -43,260.00  -2.97     False
# 81        81      San Mateo, CA        60,058.00   4.31      True
# 42        42       Honolulu, HI        36,614.00   5.11      True
# 5          5         Orange, CA        77,099.00  10.25      True
# 36        36   Contra Costa, CA        77,402.00  11.43      True
# 21        21        Alameda, CA       101,016.00  11.48      True
# 0          0    Los Angeles, CA        76,258.00  11.69      True
# 13        13           King, WA        84,047.00  13.15      True
# 16        16    Santa Clara, CA       183,758.00  16.04      True
#
#      2019-12-31   2020-01-31   2020-02-29   2020-03-31   2020-04-30  \
# 19   969,767.00   971,956.00   970,939.00   965,981.00   965,332.00
# 65 1,458,716.00 1,459,481.00 1,462,211.00 1,459,139.00 1,460,019.00
# ...

# %%
top_10_percent = top_10.sort_values('diff%')

fig, ax = plt.subplots(figsize=(10,4))
plt.rc('font', size=12) 

plt.barh(top_10_percent['county-state'],top_10_percent['diff%'],color=top_10_percent['positive'].map({True:'g', False:'r'}))
plt.title('% Change For Top 10 Counties')

ax.set_ylabel('Counties',size=12)
# ax.set_yticklabels(top_10['county-state'] + "(" +str(top_10['2019-12-31'].values) + ")")
ax.set_xlabel('% Change in Typical Home Value')

plt.tight_layout()
plt.savefig('images/top10percentchange.png')
plt.show()

# %%
top_10_dollar = top_10.sort_values('diff-cumulative')

fig, ax = plt.subplots(figsize=(10,4))
plt.rc('font', size=12) 

plt.barh(top_10_dollar['county-state'],top_10_dollar['diff-cumulative'],color=top_10_dollar['positive'].map({True:'g', False:'r'}))

plt.title('$ Change For Top 10 Counties')
ax.set_ylabel('Counties',size=12)
ax.set_xlabel('$ Change in Typical Home Value')

plt.tight_layout()
plt.savefig('images/top10dollarchange.png')
plt.show()

# %%
zillow_melt_df = pd.melt(zillow_df, id_vars=['SizeRank','county-state'],value_vars=list_dates,var_name='date', value_name='zhvi')
zillow_melt_df[zillow_melt_df['county-state'] == 'Los Angeles, CA']
zillow_melt_df.sort_values(['SizeRank','date'],inplace=True)

# %%
cov_df[cov_df['date'].isin(list_dates)]
# Out:
#                date      fips  cases  deaths     county-state
# 33       2020-01-31  4,013.00      1    0.00     Maricopa, AZ
# 34       2020-01-31  6,037.00      1    0.00  Los Angeles, CA
# 35       2020-01-31  6,059.00      1    0.00       Orange, CA
# 36       2020-01-31  6,085.00      1    0.00  Santa Clara, CA
# 37       2020-01-31 17,031.00      2    0.00         Cook, IL
# ...             ...       ...    ...     ...              ...
# 1076219  2021-02-28 56,037.00   3759   34.00   Sweetwater, WY
# 1076220  2021-02-28 56,039.00   3351    9.00        Teton, WY
# 1076221  2021-02-28 56,041.00   2053   12.00        Uinta, WY
# 1076222  2021-02-28 56,043.00    880   26.00     Washakie, WY
# 1076223  2021-02-28 56,045.00    622    5.00       Weston, WY
#
# [37173 rows x 5 columns]

# %%
ye_df = pd.DataFrame(cov_df['county-state'].unique(), columns=['county-state'])
ye_df['date'] = '2019-12-31'
ye_df['cases'] = 0
ye_df['deaths'] = 0

# %%
cov_df2 = cov_df.append(ye_df)
cov_df2.sort_values(['county-state','date'],inplace=True)

# %%
combined_df = pd.merge(cov_df2, zillow_melt_df,  how='inner', left_on=['date','county-state'], right_on = ['date','county-state'])

# %%
# combined_df['otm-cases'] = combined_df[combined_df['county-state']=='Los Angeles, CA'].cases.diff()
# combined_df.fillna(0, inplace=True)
# combined_df[combined_df['county-state']=='Los Angeles, CA']

# %%
# Number of counties in combined DF
len(combined_df['county-state'].unique())
# Out:
# 2719

# %%
# fig, ax = plt.subplots(figsize=(10,4))
# x_date = combined_df[combined_df['county-state']=='Los Angeles, CA']['date']
# y_cases = combined_df[combined_df['county-state']=='Los Angeles, CA']['otm-cases']

# ax.set_xticklabels(x_date,rotation=45)
# ax.plot(x_date, y_cases)

# %%
top_10_combined = combined_df[combined_df['county-state'].isin(top_10['county-state'])]
top_10_combined
# Out:
#              date      fips    cases    deaths       county-state  SizeRank  \
# 302    2019-12-31       NaN        0      0.00        Alameda, CA        21
# 303    2020-03-31  6,001.00      334      7.00        Alameda, CA        21
# 304    2020-04-30  6,001.00     1624     63.00        Alameda, CA        21
# 305    2020-05-31  6,001.00     3411    103.00        Alameda, CA        21
# 306    2020-06-30  6,001.00     5985    135.00        Alameda, CA        21
# 307    2020-07-31  6,001.00    11324    182.00        Alameda, CA        21
# 308    2020-08-31  6,001.00    18208    257.00        Alameda, CA        21
# 309    2020-09-30  6,001.00    21404    412.00        Alameda, CA        21
# 310    2020-10-31  6,001.00    23897    464.00        Alameda, CA        21
# 311    2020-11-30  6,001.00    29939    512.00        Alameda, CA        21
# 312    2020-12-31  6,001.00    51611    657.00        Alameda, CA        21
# ...

# %%
top_10_combined['mtm-cases'] = 0
top_10_combined = pd.merge(top_10_combined, population_df, how='left', left_on='county-state', right_on='county-state')

for county in top_10_combined['county-state'].unique():
    top_10_combined.loc[top_10_combined['county-state']==county,'mtm-cases'] = top_10_combined[top_10_combined['county-state']==county].cases.diff().fillna(0)
top_10_combined
# Out:
# /Users/tonymbp/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            date      fips    cases    deaths       county-state  SizeRank  \
# 0    2019-12-31       NaN        0      0.00        Alameda, CA        21
# 1    2020-03-31  6,001.00      334      7.00        Alameda, CA        21
# 2    2020-04-30  6,001.00     1624     63.00        Alameda, CA        21
# 3    2020-05-31  6,001.00     3411    103.00        Alameda, CA        21
# 4    2020-06-30  6,001.00     5985    135.00        Alameda, CA        21
# 5    2020-07-31  6,001.00    11324    182.00        Alameda, CA        21
# ...

# %%
top_10_combined['per-capita-cases-mtm'] = top_10_combined['mtm-cases'] / (top_10_combined['POPESTIMATE2019']/100000)
top_10_combined
# Out:
#            date      fips    cases    deaths       county-state  SizeRank  \
# 0    2019-12-31       NaN        0      0.00        Alameda, CA        21
# 1    2020-03-31  6,001.00      334      7.00        Alameda, CA        21
# 2    2020-04-30  6,001.00     1624     63.00        Alameda, CA        21
# 3    2020-05-31  6,001.00     3411    103.00        Alameda, CA        21
# 4    2020-06-30  6,001.00     5985    135.00        Alameda, CA        21
# 5    2020-07-31  6,001.00    11324    182.00        Alameda, CA        21
# 6    2020-08-31  6,001.00    18208    257.00        Alameda, CA        21
# 7    2020-09-30  6,001.00    21404    412.00        Alameda, CA        21
# 8    2020-10-31  6,001.00    23897    464.00        Alameda, CA        21
# 9    2020-11-30  6,001.00    29939    512.00        Alameda, CA        21
# 10   2020-12-31  6,001.00    51611    657.00        Alameda, CA        21
# 11   2021-01-31  6,001.00    73792    980.00        Alameda, CA        21
# ...

# %%
# fig, axes = plt.subplots(2,5, figsize=(20,20))

# for cell_ax, county in zip(axes.flatten(), top_10_combined['county-state'].unique()):
#     x_date = top_10_combined[top_10_combined['county-state']==county].sort_values('date')['date']
#     y_cases = top_10_combined[top_10_combined['county-state']==county].sort_values('date')['mtm-cases']
    
#     cell_ax.plot(x_date, y_cases)
#     cell_ax.set_title(county)
#     cell_ax.set_xticklabels(x_date,rotation=45)
    
# fig.tight_layout() 
# ax.set_xticklabels(x_date,rotation=45)

fig, ax = plt.subplots(figsize=(10,5))

for county in top_10_combined['county-state'].unique():
    x_date = top_10_combined[top_10_combined['county-state']==county]['date']
    y_cases = top_10_combined[top_10_combined['county-state']==county]['per-capita-cases-mtm']
    
    ax.plot(x_date, y_cases,label=county)
    
fig.tight_layout() 
ax.set_xticklabels(x_date,rotation=45)
# plt.yticks([100,200,300,400,500,1000,1500,2000,2500,3000,3500])
plt.legend()

# fig, ax = plt.subplots(figsize=(5,5))
# x_date = top_10_combined[top_10_combined['county-state']=='San Francisco, CA'].sort_values('date')['date']
# y_cases = top_10_combined[top_10_combined['county-state']=='San Francisco, CA'].sort_values('date')['per-capita-cases-mtm']

# ax.plot(x_date, y_cases)
# Out:
# /Users/tonymbp/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
# fig, ax = plt.subplots(figsize=(10,4))

# for county in top_10_combined['county-state']:
#     x_date = top_10_combined[top_10_combined['county-state']==county]['date']
#     y_zhvi = top_10_combined[top_10_combined['county-state']==county]['zhvi']
#     ax.plot(x_date, y_zhvi)
    
# ax.set_xticklabels(x_date,rotation=45)
# ;

# %%
y_cases.corr(y_zhvi, method='pearson')
# Out:
# nan

# %%
def county_corr(county):
    
    df = combined_df.copy()
    
    df['otm-cases'] = df[df['county-state']==county].cases.diff()
    df.fillna(0, inplace=True)    
    
    y_cases = df[df['county-state']==county]['otm-cases']
    y_zhvi = df[df['county-state']==county]['zhvi']
    
    return y_cases.corr(y_zhvi, method='pearson')

# %%
# # to test county_corr defined function
# county1 = 'San Francisco, CA'

# print(f'Correlation based on function: {county_corr(county1)}')

# cases = combined_df[combined_df['county-state']==county1]['otm-cases']
# zhvi = combined_df[combined_df['county-state']==county1]['zhvi']

# cases.corr(zhvi, method='pearson')
# print(f'Correlation based on filter: {county_corr(county1)}')

# %%
compiled_corr_df = pd.DataFrame(combined_df['county-state'].unique(),columns=['county-state'])

# %%
compiled_corr_df['correlation'] =  compiled_corr_df['county-state'].apply(county_corr)

# %%
compiled_corr_df[compiled_corr_df['county-state']=='New York City, NY']
# Out:
#            county-state  correlation
# 1801  New York City, NY        -0.62

# %%
compiled_corr_df = pd.merge(compiled_corr_df, zillow_df[['SizeRank','county-state']], how='left', left_on='county-state', right_on='county-state')
compiled_corr_df = pd.merge(compiled_corr_df, landmass_df[['county-state','land_sq_mi']], how='left', left_on='county-state', right_on='county-state')
compiled_corr_df = pd.merge(compiled_corr_df, population_df, how='left', left_on='county-state', right_on='county-state')

# %%
compiled_corr_df['pop-density'] = compiled_corr_df['POPESTIMATE2019'] / compiled_corr_df['land_sq_mi']
compiled_corr_df["rank-pop-dense"] = compiled_corr_df['pop-density'].rank(ascending=False)
compiled_corr_df.sort_values("rank-pop-dense").head()
# Out:
#            county-state  correlation  SizeRank  land_sq_mi  POPESTIMATE2019  \
# 2189  San Francisco, CA        -0.78        65       46.69           881549
# 1142         Hudson, NJ         0.59        93       46.69           672391
# 2347        Suffolk, MA         0.66        79       58.52           803907
# 1966   Philadelphia, PA         0.60        20      135.09          1584064
# 77        Arlington, VA         0.71       297       25.87           236842
#
#       pop-density  rank-pop-dense
# 2189    18,880.90            1.00
# 1142    14,401.18            2.00
# 2347    13,737.30            3.00
# 1966    11,725.99            4.00
# 77       9,155.08            5.00

# %%
fig, ax = plt.subplots(figsize=(10,6))

#scatter for top 100 counties
ax.scatter(compiled_corr_df[compiled_corr_df['SizeRank']<101].drop(compiled_corr_df.index[[1806,2189]])['correlation'], \
           compiled_corr_df[compiled_corr_df['SizeRank']<101].drop(compiled_corr_df.index[[1806,2189]])['SizeRank'],alpha=.4, \
           color='grey',label='Correlation of top 100 counties')

#scatter for top 10 counties
ax.scatter(compiled_corr_df[compiled_corr_df['county-state'].isin(top_10['county-state'])].drop(compiled_corr_df.index[[1806,2189]])['correlation'], \
           compiled_corr_df[compiled_corr_df['county-state'].isin(top_10['county-state'])].drop(compiled_corr_df.index[[1806,2189]])['SizeRank'],alpha=1, \
           color='blue',label='Correlation of top 10 counties')

#scatter for SF and NY
ax.scatter(compiled_corr_df[compiled_corr_df['county-state']=='San Francisco, CA']['correlation'], \
           compiled_corr_df[compiled_corr_df['county-state']=='San Francisco, CA']['SizeRank'], color='red', label='San Francisco, CA')
ax.scatter(compiled_corr_df[compiled_corr_df['county-state']=='New York City, NY']['correlation'], \
           compiled_corr_df[compiled_corr_df['county-state']=='Los Angeles, CA']['SizeRank'], color='orange', label='New York City, NY')

ax.set_ylabel('Size Rank by Population')
ax.set_xlabel('Correlation')
plt.title('Correlation of Top Counties')
ax.legend(facecolor='white',loc=2)

plt.tight_layout()
plt.savefig('images/corr_top_100.png')
plt.show()

# %%
df_markdown = compiled_corr_df[compiled_corr_df['county-state']\
                                .isin(top_10['county-state'])]\
                                .sort_values('correlation',ascending=False)\
                                .round({'correlation': 3})[['county-state','correlation']] 
df_markdown.rename(columns={"county-state": "County-State", "correlation": "Correlation"},inplace=True)
df_markdown.to_markdown(buf='images/corr_table',index=False)

# %% [markdown]
# # Correlation for entire USA

# %%
zhvi_usa = zillow_melt_df.groupby('date')['zhvi'].mean().reset_index()

# %%
cases_usa = cov_df2.groupby('date')['cases'].sum().reset_index()

# %%
combined_usa = pd.merge(zhvi_usa, cases_usa,  how='left', left_on=['date'], right_on = ['date'])

# %%
combined_usa['mtm-cases'] = combined_usa.cases.diff()
combined_usa.fillna(0, inplace=True)

# %%
combined_usa
# Out:
#           date       zhvi     cases    mtm-cases
# 0   2019-12-31 171,717.05         0         0.00
# 1   2020-01-31 172,087.04         7         7.00
# 2   2020-02-29 172,624.91        70        63.00
# 3   2020-03-31 173,112.60    188461   188,391.00
# 4   2020-04-30 173,527.52   1075758   887,297.00
# 5   2020-05-31 174,036.15   1799302   723,544.00
# 6   2020-06-30 174,606.51   2653321   854,019.00
# 7   2020-07-31 175,314.20   4571669 1,918,348.00
# 8   2020-08-31 176,165.45   6045455 1,473,786.00
# 9   2020-09-30 177,168.88   7262734 1,217,279.00
# 10  2020-10-31 178,336.75   9208993 1,946,259.00
# 11  2020-11-30 179,882.01  13615739 4,406,746.00
# 12  2020-12-31 181,502.68  20026890 6,411,151.00
# 13  2021-01-31 183,130.86  26220246 6,193,356.00
# 14  2021-02-28 184,781.34  28623470 2,403,224.00

# %%
cases_usa = combined_usa['mtm-cases']
zhvi_usa = combined_usa['zhvi']
date_usa = combined_usa['date']

cases_usa.corr(zhvi_usa, method='pearson')
# Out:
# 0.8247073110918928

# %%
fig, ax = plt.subplots(figsize = (10,6))

ax.plot(date_usa, zhvi_usa/1000, color='red', label='Typical Home Prices')
ax.tick_params(axis='y', labelcolor='red')
ax.set_ylabel('Average Typical Home $ (in thousands)')

# Generate a new Axes instance, on the twin-X axes (same position)
ax2 = ax.twinx()

# Plot exponential sequence, set scale to logarithmic and change tick color
ax2.plot(date_usa, cases_usa/1000000, color='green', label='COVID Cases')
ax2.tick_params(axis='y', labelcolor='green')
ax2.set_ylabel('COVID Cases (in millions)')

# ax2.yaxis.set_major_formatter(plt.ticker.FormatStrFormatter('%.2f'))
ax.set_xticks(date_usa)
ax.set_xticklabels(date_usa,rotation=45)

ax.legend(facecolor='white')
ax2.legend(facecolor='white',loc=4)
plt.title("Typical Home $ and COVID Cases Trend")

plt.tight_layout()
plt.grid(None)

plt.savefig('images/homeprices_and_cases_trend.png')
plt.show()

# %%
compiled_corr_df.nlargest(100,'POPESTIMATE2019')['POPESTIMATE2019'].sum() / compiled_corr_df['POPESTIMATE2019'].sum()
# Out:
# 0.4681952051900664
